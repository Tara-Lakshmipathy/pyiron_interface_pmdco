# %%
import pmdco
from pmdco.visualize import plot_inheritance_from_class

# %%
plot_inheritance_from_class(pmdco.Thing, max_depth=5)

# %%
plot_inheritance_from_class(pmdco.DigitalWorkflowNode, max_depth=7)

# %%
plot_inheritance_from_class(pmdco.NodePortRole, max_depth=7)

# %%
plot_inheritance_from_class(pmdco.ValueSpecification, max_depth=7)

# %%
plot_inheritance_from_class(pmdco.Software, max_depth=7)

# %%
plot_inheritance_from_class(pmdco.Thing, max_depth=1000)
